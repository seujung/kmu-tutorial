# %%
import numpy as np
import mxnet as mx
from mxnet import gluon, autograd ,nd
from mxnet.gluon import nn, utils
import mxnet.ndarray as F
import cv2

# %%
mx.__version__
# Out:
# '1.1.0'

# %% [markdown]
# ### Data loader 생성
# - gluon의 DataLoader를 활용함
# - 이미지 데이터의 경우에는 0 ~255  의 값을 가짐 -> 위 문제의 경우에는 127.5로 나눈 후 -1 을 하는 방법으로 normalization 수행
# - 기본적으로 image data형태는 NHWC(Number, Height, Width, Channel)의 형태이나 gluon의 데이터 입력 방식은 기본적으로 NCHW임 -> reshape를 수행하여서 데이터 형태를 맞춤

# %%
##load fashion-MNIST
def transform(data, label):
    return mx.nd.transpose(data.astype(np.float32), (2,0,1))/127.5 - 1, label.astype(np.float32)

train_data = gluon.data.DataLoader(
    #gluon.data.vision.FashionMNIST(train=True, transform=transform), batch_size=32, shuffle=True,last_batch='discard')
    gluon.data.vision.MNIST(train=True, transform=transform), batch_size=32, shuffle=True,last_batch='discard')

validation_data = gluon.data.DataLoader(
    #gluon.data.vision.FashionMNIST(train=False, transform=transform), batch_size=32, shuffle=False,last_batch='discard')
    gluon.data.vision.MNIST(train=False, transform=transform), batch_size=32, shuffle=False,last_batch='discard')
# Out:
# Downloading /home/seunghwan_2/.mxnet/datasets/mnist/train-images-idx3-ubyte.gz from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/dataset/mnist/train-images-idx3-ubyte.gz...
# Downloading /home/seunghwan_2/.mxnet/datasets/mnist/train-labels-idx1-ubyte.gz from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/dataset/mnist/train-labels-idx1-ubyte.gz...
# /opt/venv/lib/python3.6/site-packages/mxnet/gluon/data/vision/datasets.py:118: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   label = np.fromstring(fin.read(), dtype=np.uint8).astype(np.int32)
# /opt/venv/lib/python3.6/site-packages/mxnet/gluon/data/vision/datasets.py:122: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   data = np.fromstring(fin.read(), dtype=np.uint8)
# Downloading /home/seunghwan_2/.mxnet/datasets/mnist/t10k-images-idx3-ubyte.gz from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/dataset/mnist/t10k-images-idx3-ubyte.gz...
# Downloading /home/seunghwan_2/.mxnet/datasets/mnist/t10k-labels-idx1-ubyte.gz from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/dataset/mnist/t10k-labels-idx1-ubyte.gz...

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#imgplot = plt.imshow(X[0][0] * 255,cmap='gray')
#plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 학습을 위한 hyperparameter을 설정함
# - epoches : 총 Epoch 크기
# - batch size : 네트워크에 투입되는 Data 크기
# - latent_z_size : random data 크기
# - use_gpu : gpu 사용 여부
# - ctx : Context의 의미로 gluon 에서는 데이터 처리를 cpu 에서 할지 gpu에서 할지를 ctx를 통해 지정해줌(default : cpu)
# - lr : learning rate

# %%
epochs = 20 
batch_size = 32
latent_z_size = 100

use_gpu = True
ctx = mx.gpu() if use_gpu else mx.cpu()

lr = 0.0002
beta1 = 0.5

# %% [markdown]
# #### Generator 설정
# - 기본적으로 Generator와 Discriminator가 동일한 형태로 되어 있음 (정방향/역방향)
# - Generator의 경우에는 Conv2DTranspose를 활용함
# - 데이터 크기의 변화 과정 (Channel X Height X Width)
#    - Input Data : 100 X 1 X 1
#    - 1st Conv2DTr. : (64*8) X 4 X 4
#    - 2nd Conv2DTr. :  (64*4) X 8 X 8
#    - 3rd Conv2DTr. :  (64*2) X 16 X 16
#    - 4th Conv2DTr. :  (64*1) X 32 X 32
#    - 5th Conv2DTr. :  1 X 64 X 64

# %%
# build the generator
nc = 1
ngf = 32
netG = nn.Sequential()
with netG.name_scope():
    # input is Z, going into a convolution
    netG.add(nn.Conv2DTranspose(ngf * 8, 4, 1, 0, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 4 x 4
    netG.add(nn.Conv2DTranspose(ngf * 4, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*4) x 8 x 8
    netG.add(nn.Conv2DTranspose(ngf * 2, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*2) x 16 x 16
    netG.add(nn.Conv2DTranspose(ngf, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. () x 32 x 32
    netG.add(nn.Conv2DTranspose(nc, 3, 1, 1, use_bias=False))
    netG.add(nn.Activation('tanh'))
    # state size. (nc) x 64 x 64

# %% [markdown]
# #### Discriminator 설정
# - Discriminator 경우에는 Conv2D를 활용함
# - 데이터 크기의 변화 과정 (Channel X Height X Width)
#    - Input Data    : 1 X 64 X 64
#    - 1st Conv2DTr. :  (64*1) X 32 X 32
#    - 2nd Conv2DTr. :  (64*2) X 16 X 16
#    - 3rd Conv2DTr. :  (64*4) X 8 X 8
#    - 4th Conv2DTr. :  (64*8) X 4 X 4
#    - 5th Conv2DTr. :  64 X 1 X 1

# %%
# build the discriminator
ndf = 32
netD = nn.Sequential()
with netD.name_scope():
    # input is (nc) x 64 x 64
    netD.add(nn.Conv2D(ndf, 3, 1, 1, use_bias=False))
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 32 x 32
    netD.add(nn.Conv2D(ndf * 2, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf*2) x 16 x 16
    netD.add(nn.Conv2D(ndf * 4, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf*4) x 8 x 8
    netD.add(nn.Conv2D(ndf * 8, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf*8) x 4 x 4
    netD.add(nn.Conv2D(1, 4, 1, 0, use_bias=False))
    # state size. (ndf) x 1 x 1

# %% [markdown]
# ### loss 및 optimizer 정의
# - 해당 문제에서는 sigmoid Binary CrossEntropy를 적용
# - gluon에서 네트워크를 활용하기 위해서는 parameter에 대한 초기화 작업이 필요
# - optimizer의 경우에는 Adam을 적용

# %%
# loss
loss = gluon.loss.SigmoidBinaryCrossEntropyLoss()
# initialize the generator and the discriminator
netG.initialize(mx.init.Normal(0.02), ctx=ctx)
netD.initialize(mx.init.Normal(0.02), ctx=ctx)

# trainer for the generator and the discriminator
trainerG = gluon.Trainer(netG.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})
trainerD = gluon.Trainer(netD.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})

# %%
netG
# Out:
# Sequential(
#   (0): Conv2DTranspose(256 -> 0, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=None)
#   (2): Activation(relu)
#   (3): Conv2DTranspose(128 -> 0, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=None)
#   (5): Activation(relu)
#   (6): Conv2DTranspose(64 -> 0, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=None)
#   (8): Activation(relu)
#   (9): Conv2DTranspose(32 -> 0, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (10): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=None)
#   (11): Activation(relu)
#   (12): Conv2DTranspose(1 -> 0, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): Activation(tanh)
# )

# %%
netD
# Out:
# Sequential(
#   (0): Conv2D(None -> 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (1): LeakyReLU(0.2)
#   (2): Conv2D(None -> 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (3): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=None)
#   (4): LeakyReLU(0.2)
#   (5): Conv2D(None -> 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (6): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=None)
#   (7): LeakyReLU(0.2)
#   (8): Conv2D(None -> 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (9): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=None)
#   (10): LeakyReLU(0.2)
#   (11): Conv2D(None -> 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )

# %%
from datetime import datetime
import time
import logging

real_label = nd.ones((batch_size,), ctx=ctx)
fake_label = nd.zeros((batch_size,),ctx=ctx)

def facc(label, pred):
    pred = pred.ravel()
    label = label.ravel()
    return ((pred > 0.5) == label).mean()
metric = mx.metric.CustomMetric(facc)

stamp =  datetime.now().strftime('%Y_%m_%d-%H_%M')
logging.basicConfig(level=logging.DEBUG)

for epoch in range(epochs):
    tic = time.time()
    btic = time.time()
    iter = 0
    for (data, label) in train_data:
        # 원래 데이터 형태는 1 X 28 X 28임 -> DCGAN 네트워크 활용을 위해서 이미지 데이터의 크기를 조절
        X = np.zeros((batch_size, 28, 28))
        for idx in range(data.shape[0]):
            X[idx] = data.asnumpy()[idx,0,:,:]
        X = np.asarray([cv2.resize(x, (32,32)) for x in X])
        X = X.reshape((batch_size,1,32,32))
        data = nd.array(X,ctx=ctx)
        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        latent_z = mx.nd.random_normal(0, 1, shape=(batch_size, latent_z_size, 1, 1), ctx=ctx)
    
        #Gradient를 산출 및 이를 Back prop.에 적용
        with autograd.record():
            # train with real image
            output = netD(data).reshape((-1, 1))
            errD_real = loss(output, real_label)
            metric.update([real_label,], [output,])

            # train with fake image
            fake = netG(latent_z)
            output = netD(fake.detach()).reshape((-1, 1))
            errD_fake = loss(output, fake_label)
            errD = errD_real + errD_fake
            errD.backward()
            metric.update([fake_label,], [output,])

        trainerD.step(data.shape[0])

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        with autograd.record():
            fake = netG(latent_z)
            output = netD(fake).reshape((-1, 1))
            errG = loss(output, real_label)
            errG.backward()

        trainerG.step(data.shape[0])

        # Print log infomation every ten batches
        if iter % 100 == 0:
            name, acc = metric.get()
            logging.info('speed: {} samples/s'.format(batch_size / (time.time() - btic)))
            logging.info('discriminator loss = %f, generator loss = %f, binary training acc = %f at iter %d epoch %d'
                     %(nd.mean(errD).asscalar(),
                       nd.mean(errG).asscalar(), acc, iter, epoch))
            fake_img = fake[0][0].asnumpy()
            imgplot = plt.imshow((fake_img +1)*127.5,cmap='gray')
            plt.show()
        iter = iter + 1
        btic = time.time()

    name, acc = metric.get()
    metric.reset()
    # logging.info('\nbinary training acc at epoch %d: %s=%f' % (epoch, name, acc))
    # logging.info('time: %f' % (time.time() - tic))

    # Visualize one generated image for each epoch
# Out:
# INFO:root:speed: 65.591727346476 samples/s
# INFO:root:discriminator loss = 1.871912, generator loss = 1.913152, binary training acc = 0.468750 at iter 0 epoch 0
# DEBUG:matplotlib.font_manager:findfont: Matching :family=NanumGothicCoding:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to NanumGothicCoding ('/usr/share/fonts/truetype/nanum/NanumGothic_Coding.ttf') with score of 0.050000
# INFO:root:speed: 975.809575048166 samples/s
# INFO:root:discriminator loss = 0.114899, generator loss = 6.184165, binary training acc = 0.957457 at iter 100 epoch 0
# INFO:root:speed: 1344.0185854620831 samples/s
# INFO:root:discriminator loss = 0.099808, generator loss = 4.135401, binary training acc = 0.948305 at iter 200 epoch 0
# INFO:root:speed: 599.0793072665596 samples/s
# INFO:root:discriminator loss = 0.894249, generator loss = 10.964575, binary training acc = 0.940044 at iter 300 epoch 0
# INFO:root:speed: 231.81835579244807 samples/s
# INFO:root:discriminator loss = 0.337287, generator loss = 3.428127, binary training acc = 0.936877 at iter 400 epoch 0
# INFO:root:speed: 1341.4931185095602 samples/s
# INFO:root:discriminator loss = 0.206258, generator loss = 3.744957, binary training acc = 0.937438 at iter 500 epoch 0
# INFO:root:speed: 1236.9955485101793 samples/s
# INFO:root:discriminator loss = 0.270714, generator loss = 2.901651, binary training acc = 0.927569 at iter 600 epoch 0
# INFO:root:speed: 511.2978392710206 samples/s
# INFO:root:discriminator loss = 0.325208, generator loss = 2.459624, binary training acc = 0.924884 at iter 700 epoch 0
# INFO:root:speed: 1232.780351599096 samples/s
# INFO:root:discriminator loss = 0.218643, generator loss = 3.656578, binary training acc = 0.925484 at iter 800 epoch 0
# INFO:root:speed: 1209.3757309809787 samples/s
# INFO:root:discriminator loss = 0.143216, generator loss = 4.414450, binary training acc = 0.923470 at iter 900 epoch 0
# INFO:root:speed: 1216.3352364381128 samples/s
# INFO:root:discriminator loss = 0.810043, generator loss = 0.885251, binary training acc = 0.920486 at iter 1000 epoch 0
# INFO:root:speed: 1148.052998486002 samples/s
# INFO:root:discriminator loss = 0.907979, generator loss = 11.442805, binary training acc = 0.956261 at iter 1100 epoch 2
# INFO:root:speed: 1376.2392002050756 samples/s
# INFO:root:discriminator loss = 0.428251, generator loss = 2.605912, binary training acc = 0.952553 at iter 1200 epoch 2
# INFO:root:speed: 1272.555754662419 samples/s
# INFO:root:discriminator loss = 0.175131, generator loss = 4.244778, binary training acc = 0.951888 at iter 1300 epoch 2
# INFO:root:speed: 1111.0095275935996 samples/s
# INFO:root:discriminator loss = 0.762092, generator loss = 8.991383, binary training acc = 0.954385 at iter 1400 epoch 2
# INFO:root:speed: 1284.0729777565175 samples/s
# INFO:root:discriminator loss = 0.015445, generator loss = 7.045170, binary training acc = 0.956977 at iter 1500 epoch 2
# INFO:root:speed: 1222.4616141284052 samples/s
# INFO:root:discriminator loss = 0.102554, generator loss = 5.085771, binary training acc = 0.957761 at iter 1600 epoch 2
# INFO:root:speed: 1141.967532246537 samples/s
# INFO:root:discriminator loss = 0.036259, generator loss = 6.463686, binary training acc = 0.954797 at iter 1700 epoch 2
# INFO:root:speed: 1060.2637511948114 samples/s
# INFO:root:discriminator loss = 0.093371, generator loss = 4.357123, binary training acc = 0.954461 at iter 1800 epoch 2
# INFO:root:speed: 362.69572172860325 samples/s
# INFO:root:discriminator loss = 0.074153, generator loss = 4.509491, binary training acc = 1.000000 at iter 0 epoch 3
# INFO:root:speed: 1337.7893309943386 samples/s
# INFO:root:discriminator loss = 0.059841, generator loss = 4.477378, binary training acc = 0.931621 at iter 100 epoch 3
# INFO:root:speed: 1219.2854949627085 samples/s
# INFO:root:discriminator loss = 0.111249, generator loss = 4.660262, binary training acc = 0.945740 at iter 200 epoch 3
# INFO:root:speed: 1282.8088848109492 samples/s
# INFO:root:discriminator loss = 0.108159, generator loss = 4.626291, binary training acc = 0.956447 at iter 300 epoch 3
# INFO:root:speed: 1213.0921448649235 samples/s
# INFO:root:discriminator loss = 0.087016, generator loss = 2.580987, binary training acc = 0.950631 at iter 400 epoch 3
# INFO:root:speed: 1178.5580639779423 samples/s
# INFO:root:discriminator loss = 0.126835, generator loss = 3.474238, binary training acc = 0.955963 at iter 500 epoch 3
# INFO:root:speed: 1231.9543264155966 samples/s
# INFO:root:discriminator loss = 0.085274, generator loss = 3.984334, binary training acc = 0.962640 at iter 600 epoch 3
# INFO:root:speed: 1025.6981238775745 samples/s
# INFO:root:discriminator loss = 0.105444, generator loss = 4.764548, binary training acc = 0.955332 at iter 700 epoch 3
# INFO:root:speed: 1035.2791336274722 samples/s
# INFO:root:discriminator loss = 0.060211, generator loss = 3.462570, binary training acc = 0.958567 at iter 800 epoch 3
# INFO:root:speed: 806.2625954381897 samples/s
# INFO:root:discriminator loss = 0.551779, generator loss = 1.735532, binary training acc = 0.960634 at iter 900 epoch 3
# INFO:root:speed: 1045.9203428794078 samples/s
# INFO:root:discriminator loss = 0.127902, generator loss = 3.900441, binary training acc = 0.956887 at iter 1000 epoch 3
# INFO:root:speed: 1030.130230559052 samples/s
# INFO:root:discriminator loss = 0.077072, generator loss = 3.347375, binary training acc = 0.958688 at iter 1100 epoch 3
# INFO:root:speed: 1089.0406672941483 samples/s
# INFO:root:discriminator loss = 0.045595, generator loss = 3.965725, binary training acc = 0.960463 at iter 1200 epoch 3
# INFO:root:speed: 1337.5093722907054 samples/s
# INFO:root:discriminator loss = 0.101909, generator loss = 3.748982, binary training acc = 0.962024 at iter 1300 epoch 3
# INFO:root:speed: 1089.4119251310856 samples/s
# INFO:root:discriminator loss = 0.689403, generator loss = 10.174833, binary training acc = 0.962839 at iter 1400 epoch 3
# INFO:root:speed: 1334.5171515501024 samples/s
# INFO:root:discriminator loss = 0.035938, generator loss = 4.631895, binary training acc = 0.960828 at iter 1500 epoch 3
# INFO:root:speed: 1345.6220725056144 samples/s
# INFO:root:discriminator loss = 0.378866, generator loss = 5.145464, binary training acc = 0.961928 at iter 1600 epoch 3
# INFO:root:speed: 1192.156327719747 samples/s
# INFO:root:discriminator loss = 0.036180, generator loss = 5.186328, binary training acc = 0.960520 at iter 1700 epoch 3
# INFO:root:speed: 993.5356759517658 samples/s
# INFO:root:discriminator loss = 0.245841, generator loss = 3.690242, binary training acc = 0.962226 at iter 1800 epoch 3
# INFO:root:speed: 431.53634297142014 samples/s
# INFO:root:discriminator loss = 0.235534, generator loss = 5.485085, binary training acc = 0.984375 at iter 0 epoch 4
# INFO:root:speed: 1156.1922023327534 samples/s
# INFO:root:discriminator loss = 0.110964, generator loss = 5.549799, binary training acc = 0.962717 at iter 100 epoch 4
# INFO:root:speed: 1366.2506158513 samples/s
# INFO:root:discriminator loss = 0.061604, generator loss = 5.169557, binary training acc = 0.971782 at iter 200 epoch 4
# INFO:root:speed: 1356.597915845437 samples/s
# INFO:root:discriminator loss = 0.171967, generator loss = 4.312001, binary training acc = 0.968646 at iter 300 epoch 4
# INFO:root:speed: 1295.0379004245465 samples/s
# INFO:root:discriminator loss = 0.031853, generator loss = 5.345871, binary training acc = 0.973815 at iter 400 epoch 4
# INFO:root:speed: 837.0245773334747 samples/s
# INFO:root:discriminator loss = 0.014274, generator loss = 7.659260, binary training acc = 0.978761 at iter 500 epoch 4
# INFO:root:speed: 513.1372862369677 samples/s
# INFO:root:discriminator loss = 2.110245, generator loss = 10.081457, binary training acc = 0.972702 at iter 600 epoch 4
# INFO:root:speed: 1065.1101711728154 samples/s
# INFO:root:discriminator loss = 0.055377, generator loss = 4.237731, binary training acc = 0.969708 at iter 700 epoch 4
# INFO:root:speed: 933.5976183189116 samples/s
# INFO:root:discriminator loss = 0.016152, generator loss = 6.054081, binary training acc = 0.972086 at iter 800 epoch 4
# INFO:root:speed: 1120.4231334312808 samples/s
# INFO:root:discriminator loss = 0.726411, generator loss = 5.364893, binary training acc = 0.968022 at iter 900 epoch 4
# INFO:root:speed: 1201.4297811395068 samples/s
# INFO:root:discriminator loss = 0.252400, generator loss = 3.027928, binary training acc = 0.962865 at iter 1000 epoch 4
# INFO:root:speed: 1379.7478129465342 samples/s
# INFO:root:discriminator loss = 0.514472, generator loss = 7.085707, binary training acc = 0.960150 at iter 1100 epoch 4
# INFO:root:speed: 518.9184106646459 samples/s
# INFO:root:discriminator loss = 0.157176, generator loss = 3.786036, binary training acc = 0.961699 at iter 1200 epoch 4
# INFO:root:speed: 1040.1733496597797 samples/s
# INFO:root:discriminator loss = 0.052933, generator loss = 6.262258, binary training acc = 0.962637 at iter 1300 epoch 4
# INFO:root:speed: 945.0022741834414 samples/s
# INFO:root:discriminator loss = 0.036680, generator loss = 5.114157, binary training acc = 0.964635 at iter 1400 epoch 4
# INFO:root:speed: 464.0599118333477 samples/s
# INFO:root:discriminator loss = 0.475260, generator loss = 1.702266, binary training acc = 0.964368 at iter 1500 epoch 4
# INFO:root:speed: 548.1876988551661 samples/s
# INFO:root:discriminator loss = 0.048776, generator loss = 5.425301, binary training acc = 0.962377 at iter 1600 epoch 4
# INFO:root:speed: 1114.1174400265627 samples/s
# INFO:root:discriminator loss = 0.519330, generator loss = 5.417255, binary training acc = 0.962596 at iter 1700 epoch 4
# INFO:root:speed: 352.49214219682324 samples/s
# INFO:root:discriminator loss = 0.019854, generator loss = 5.586835, binary training acc = 0.964091 at iter 1800 epoch 4
# INFO:root:speed: 422.08160005031607 samples/s
# INFO:root:discriminator loss = 0.070425, generator loss = 3.754102, binary training acc = 0.984375 at iter 0 epoch 5
# INFO:root:speed: 1186.7068195683505 samples/s
# INFO:root:discriminator loss = 0.022712, generator loss = 4.605941, binary training acc = 0.997989 at iter 100 epoch 5
# INFO:root:speed: 1361.4140606773713 samples/s
# INFO:root:discriminator loss = 0.011743, generator loss = 5.929238, binary training acc = 0.998678 at iter 200 epoch 5
# INFO:root:speed: 860.5520911474863 samples/s
# INFO:root:discriminator loss = 0.110307, generator loss = 4.767594, binary training acc = 0.978042 at iter 300 epoch 5
# INFO:root:speed: 174.23723251237155 samples/s
# INFO:root:discriminator loss = 0.109707, generator loss = 5.187083, binary training acc = 0.980206 at iter 400 epoch 5
# INFO:root:speed: 1166.3398797316556 samples/s
# INFO:root:discriminator loss = 0.042167, generator loss = 5.733851, binary training acc = 0.973366 at iter 500 epoch 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-51d10928245a> in <module>()
#      44             errD_fake = loss(output, fake_label)
#      45             errD = errD_real + errD_fake
# ---> 46             errD.backward()
#      47             metric.update([fake_label,], [output,])
#      48
#
# /opt/venv/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in backward(self, out_grad, retain_graph, train_mode)
#    2000             ctypes.c_int(train_mode),
#    2001             ctypes.c_void_p(0),
# -> 2002             ctypes.c_void_p(0)))
#    2003
#    2004     def tostype(self, stype):
#
# KeyboardInterrupt:

# %%
latent_z = mx.nd.random_normal(0, 1, shape=(16, latent_z_size, 1, 1), ctx=ctx)

# %%
fake = netG(latent_z)

# %%
fake.shape
# Out:
# (16, 1, 32, 32)

# %%
fig=plt.figure(figsize=(10, 10))
columns = 4
rows = 4
for i in range(fake.shape[0]):
    fake_img = fake[i][0].asnumpy()
    fig.add_subplot(rows, columns, i+1)
    plt.imshow((fake_img +1)*127.5,cmap='gray')
plt.show()
